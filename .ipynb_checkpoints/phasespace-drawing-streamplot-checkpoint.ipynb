# %%
from pylab import *

#IM MESSING AROUND WITH THIS RN IT DOESNT MEAN ANYTHING
rhoX = 0.121
rhoY = 1
Ax = 1.421
Kx = 4.792
Ky = 0.544
k = 1
a = 1
b = 1
c = 1
d = 1
h = 1
p = 1
g = 1

x, y = meshgrid(arange(0, 5, 0.1), arange(0, 5, 0.1))

#original equations (SINDy compatable)
xdot = (rhoX - (a/h)*y - ((b*h-a*k)/(h**2))*y**2)*x + (rhoX/Ax - rhoX/Kx)*(x**2) - (rhoX/(Kx*Ax))*(x**3)
ydot = (rhoY + p/g + (1 - c/h)*x - (p/(g**2))*(x**2)+(p/g**3)*(x**3))*y + (-rhoY/Ky - (d*h-c*k)/(h**2))*(y**2)

#term-separated equations


streamplot(x, y, xdot, ydot)
show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#HIGH E:T discovered model phasespace visualization
x1 = 0.121
x2 = 0.061
x3 = -0.018
x1y2 = -0.593

y1 = 0.191
y2 = -0.351
x1y1 = 0.035
x2y1 = -0.009

x, y = meshgrid(arange(0, 4, 0.3), arange(0, 4, 0.3))

xdot = x1*x + x2*(x**2) + x3 * (x**3) + x1y2*x*(y**2)
ydot = y1*y + y2*(y**2) + x1y1*x*y + x2y1*(x**2)*y

streamplot(x, y, xdot, ydot)
show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#MEDIUM E:T discovered model phasespace visualization
x1 = 0.237
x2 = 0.04
x3 = -0.012
x1y1 = -0.626

y1 = 0.112
y2 = -0.358
x1y1 = 0.051
x2y1 = -0.009

x, y = meshgrid(arange(0, 12, 0.3), arange(0, 5, 0.3))

xdot = x1*x + x2*(x**2) + x3 * (x**3) + x1y1*x*y
ydot = y1*y + y2*(y**2) + x1y1*x*y + x2y1*(x**2)*y

streamplot(x, y, xdot, ydot)
show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#LOW E:T discovered model phasespace visualization
x1 = 0.150
x2 = -0.012
x1y1X = -0.545

x1y1Y = -0.002
x2y1 = 0.005
x1y2 = -0.063

x, y = meshgrid(arange(0, 2, 0.05), arange(0, 2, 0.05))

xdot = x1*x + x2*(x**2) + x1y1X*x*y
ydot = x1y1Y*x*y + x2y1*(x**2)*y + x1y2*x*(y**2)

streamplot(x, y, xdot, ydot)
show()
